# %%
# !python -V
# Out:
# Python 3.9.12

# %%
import os
import mlflow
import pickle
import zipfile
import datetime
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from typing import List
from hyperopt.pyll import scope
from mlflow.tracking import MlflowClient
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# !pip freeze | grep scikit-learn
# Out:
# scikit-learn==1.1.1

# %%
MLFLOW_TRACKING_URI = os.getenv('MLFLOW_TRACKING_URI', 'http://ec2-54-79-228-176.ap-southeast-2.compute.amazonaws.com:5000/')
EXPERIMENT_NAME = os.getenv('EXPERIMENT_NAME', 'bikeshare-ride-duration-prediction')
MODEL_NAME = os.getenv('MODEL_NAME', 'bikeshare-ride-duration-regressor')
TRAINING_DATA_PATH = os.getenv('TRAINING_DATA_PATH', 'https://s3.amazonaws.com/capitalbikeshare-data/202204-capitalbikeshare-tripdata.zip')
TEST_DATA_PATH = os.getenv('TEST_DATA_PATH', 'https://s3.amazonaws.com/capitalbikeshare-data/202205-capitalbikeshare-tripdata.zip')

# %%
def read_data(url: str):
    """
    Capital Bikeshare datasets are zipped
    We need to download then extract the csv
    """
    zip_path = url.split('/')[-1] 
    file_name = zip_path.split('.')[0] + '.csv'
    save_path = f'./datasets/{zip_path}'

    req = requests.get(url)

    with open(save_path, 'wb') as f_out:
        f_out.write(req.content)

    with zipfile.ZipFile(save_path) as z:
        with z.open(file_name) as f:
            df = pd.read_csv(f, parse_dates=True)
            
    categorical_cols = ['rideable_type', 'start_station_id', 'end_station_id']
    date_cols = ['started_at', 'ended_at']
    
    df[categorical_cols] = df[categorical_cols].astype(str)
    df[date_cols] = df[date_cols].apply(pd.to_datetime, format='%Y/%m/%d %H:%M:%S')
    
    df['duration'] = df['ended_at'] - df['started_at']
    df['duration'] = df['duration'].apply(lambda x: round(x.total_seconds() / 60, 0))
    df['start_end'] = df['start_station_id'] + '_' + df['end_station_id']

    df = df[df['duration'] <= 120]

    categorical_cols = ['rideable_type', 'start_end']
    target = 'duration'
    
    return df, categorical_cols, target

# %%
df, categorical_cols, target = read_data(TRAINING_DATA_PATH)

# %%
df.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  8F5ADBABCB4EBE01  classic_bike 2022-04-15 10:09:53 2022-04-15 10:16:12
# 2  01BF0E3746A32678  classic_bike 2022-04-20 19:35:59 2022-04-20 19:41:04
# 3  94BD7902E9889076   docked_bike 2022-04-15 17:23:21 2022-04-15 17:48:35
# 4  2CA1C29600E5F00A  classic_bike 2022-04-18 09:04:07 2022-04-18 09:05:12
# 5  25DFD58A2EE108E1  classic_bike 2022-04-20 10:29:37 2022-04-20 10:54:07
#
#                         start_station_name start_station_id  \
# 0                    Maine Ave & 9th St SW          31646.0
# 2                           11th & V st NW          31332.0
# 3  14th & D St NW / Ronald Reagan Building          31231.0
# 4                           11th & V st NW          31332.0
# 5                           11th & V st NW          31332.0
#
#                                     end_station_name end_station_id  \
# 0  Smithsonian-National Mall / Jefferson Dr & 12t...        31248.0
# 2                               14th & Belmont St NW        31119.0
# 3                                     15th & W St NW        31125.0
# 4                                     11th & V st NW        31332.0
# 5                    Montello Ave & Holbrook Terr NE        31524.0
#
#    start_lat  start_lng    end_lat    end_lng member_casual  duration  \
# 0  38.880440 -77.025236  38.888774 -77.028694        member       6.0
# 2  38.918199 -77.027171  38.921074 -77.031887        member       5.0
# 3  38.894514 -77.031617  38.919019 -77.034449        casual      25.0
# 4  38.918199 -77.027171  38.918199 -77.027171        member       1.0
# 5  38.918199 -77.027171  38.907444 -76.986813        member      24.0
#
#          start_end
# 0  31646.0_31248.0
# 2  31332.0_31119.0
# 3  31231.0_31125.0
# 4  31332.0_31332.0
# 5  31332.0_31524.0

# %%
def create_train_val_sets(df: pd.DataFrame, categorical_cols: List, target: str):
    dv = DictVectorizer()
    dicts = df[categorical_cols].to_dict(orient='records')
    
    x = dv.fit_transform(dicts)
    y = df[target].values

    x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, shuffle=True, random_state=42)
    print(x_train.shape, x_val.shape, y_train.shape, y_val.shape)
    print(dv)

    return x_train, x_val, y_train, y_val, dv

# %%
x_train, x_val, y_train, y_val, dv = create_train_val_sets(df, categorical_cols, target)
# Out:
# (243756, 54362) (60939, 54362) (243756,) (60939,)
# DictVectorizer()

# %%
lr = Ridge().fit(x_train, y_train)
y_pred = lr.predict(x_val)
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 14.405431269954295

# %%
def model_search(x_train, y_train, x_val, y_val, num_trials=10):
    
    def objective(params):
        
        with mlflow.start_run():
            mlflow.set_tag('model', 'Ridge')
            mlflow.log_params(params)
            
            lr = Ridge(**params)
            lr.fit(x_train, y_train)
            y_pred = lr.predict(x_val)
            rmse = mean_squared_error(y_val, y_pred, squared=False)
            mlflow.log_metric('RMSE', rmse)

        return {'loss': rmse, 'status': STATUS_OK}

    search_space = {
        'alpha': hp.uniform('alpha', 0.01, 1)
    }

    rstate=np.random.default_rng(0)
    best_result = fmin(
        fn=objective,
        space=search_space,
        algo=tpe.suggest,
        max_evals=num_trials,
        trials=Trials(),
        rstate=rstate
    )

    return best_result

# %%
def train_best_model(x_train, y_train, x_val, y_val, dv, best_result):
    
    with mlflow.start_run() as run:
        
        print(f"Best params: {best_result}")
        mlflow.log_params(best_result)
        lr = Ridge(**best_result)
        lr.fit(x_train, y_train)
        y_pred = lr.predict(x_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        print(f"RMSE: {rmse}")
        mlflow.log_metric('RMSE', rmse)

        with open('preprocessor.bin', 'wb') as f_out:
            pickle.dump(dv, f_out)
        mlflow.log_artifact('preprocessor.bin', artifact_path='preprocessor')
        mlflow.sklearn.log_model(lr, artifact_path='model')

        run_id = run.info.run_id
        print(f'Run ID: {run_id}')
        model_uri = f'runs:/{run_id}/model'
        mlflow.register_model(model_uri=model_uri, name=MODEL_NAME)

    return run_id

# %%
def transition_model_stage(client, model_name, model_version, stage):
    client.transition_model_version_stage(
        name=model_name,
        version=model_version,
        stage=stage,
        archive_existing_versions=False
    )

    date = datetime.date.today()
    client.update_model_version(
        name=model_name,
        version=model_version,
        description=f'Version {model_version} of {model_name} was transitioned to {stage} on {date}.'
    )

# %%
def train_model(client, data_path=TRAINING_DATA_PATH):
    
    df, categorical_cols, target = read_data(data_path)
    x_train, x_val, y_train, y_val, dv = create_train_val_sets(df, categorical_cols, target)

    best_result = model_search(x_train, y_train, x_val, y_val)
    train_best_model(x_train, y_train, x_val, y_val, dv, best_result)

    model_version = client.get_latest_versions(MODEL_NAME)[-1].version
    transition_model_stage(client, MODEL_NAME, model_version, 'Staging')

# %%
def get_model_preprocessor_paths(client, run_id: str):
    experiment = client.get_experiment_by_name(EXPERIMENT_NAME)
    artifact_location = experiment.artifact_location
    model_path = f'{artifact_location}/{run_id}/artifacts/model'
    preprocessor_path = f'{artifact_location}/{run_id}/artifacts/preprocessor/preprocessor.bin'

    return model_path, preprocessor_path

# %%
def load_model_preprocessor(client, run_id: str):
    model_path, preprocessor_path = get_model_preprocessor_paths(run_id)
    model = mlflow.pyfunc.load_model(model_path)
    preprocessor_artifact = mlflow.artifacts.download_artifacts(preprocessor_path)
    
    with open(preprocessor_artifact, 'rb') as f_in:
        preprocessor = pickle.load(f_in)

    return model, preprocessor

# %%
def test_model(client, model_name, data_path=TEST_DATA_PATH):

    df, categorical_cols, target = read_data(data_path)
    dv = mlflow
    production_model = client.
    y_pred = lr.predict(x_val)
    mean_squared_error(y_val, y_pred, squared=False)

# %%
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
client.list_experiments()
# Out:
# [<Experiment: artifact_location='s3://mlflow-artifacts-remote-2/0', experiment_id='0', lifecycle_stage='active', name='Default', tags={}>,
#  <Experiment: artifact_location='s3://mlflow-artifacts-remote-2/1', experiment_id='1', lifecycle_stage='active', name='bikeshare-ride-duration-prediction', tags={}>]

# %%
client.search_runs([1])
# Out:
# [<Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.log-model.history': '[{"run_id": "b9ea23fdd14043a8827497b800da057f", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2022-09-08 11:47:20.501657", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"loader_module": "mlflow.sklearn", '
#                               '"python_version": "3.9.12", "env": '
#                               '"conda.yaml"}, "sklearn": {"pickled_model": '
#                               '"model.pkl", "sklearn_version": "1.0.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"821d12e1330941298edfc564a4fdea6e", '
#                               '"mlflow_version": "1.28.0"}]',
#   'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/b9ea23fdd14043a8827497b800da057f/artifacts', end_time=1662637643483, experiment_id='1', lifecycle_stage='active', run_id='b9ea23fdd14043a8827497b800da057f', run_uuid='b9ea23fdd14043a8827497b800da057f', start_time=1662637636416, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.411816641532287}, params={'alpha': '0.3406991284146929'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/5975d75082e3428392c32dbc7303687b/artifacts', end_time=1662637636185, experiment_id='1', lifecycle_stage='active', run_id='5975d75082e3428392c32dbc7303687b', run_uuid='5975d75082e3428392c32dbc7303687b', start_time=1662637635109, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.394184574038444}, params={'alpha': '0.506849894895767'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/57e0776914da4b33be190ccca38116ba/artifacts', end_time=1662637635018, experiment_id='1', lifecycle_stage='active', run_id='57e0776914da4b33be190ccca38116ba', run_uuid='57e0776914da4b33be190ccca38116ba', start_time=1662637634040, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.455377317732182}, params={'alpha': '0.16793791172232522'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/ad3291b53a484f4aa7ec4bcbf39777f1/artifacts', end_time=1662637633933, experiment_id='1', lifecycle_stage='active', run_id='ad3291b53a484f4aa7ec4bcbf39777f1', run_uuid='ad3291b53a484f4aa7ec4bcbf39777f1', start_time=1662637632855, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.391526068627218}, params={'alpha': '0.7321554052259304'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/edcc33026fcd43198d2300c5fe58df51/artifacts', end_time=1662637632758, experiment_id='1', lifecycle_stage='active', run_id='edcc33026fcd43198d2300c5fe58df51', run_uuid='edcc33026fcd43198d2300c5fe58df51', start_time=1662637631770, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.405640754327791}, params={'alpha': '0.9983678625682587'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/70d87b21df064f5c9b479326f0970bf3/artifacts', end_time=1662637631682, experiment_id='1', lifecycle_stage='active', run_id='70d87b21df064f5c9b479326f0970bf3', run_uuid='70d87b21df064f5c9b479326f0970bf3', start_time=1662637630701, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39193708706294}, params={'alpha': '0.5509362875686761'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/5a71d131c4bc47d198bc2ed1340ca15e/artifacts', end_time=1662637630555, experiment_id='1', lifecycle_stage='active', run_id='5a71d131c4bc47d198bc2ed1340ca15e', run_uuid='5a71d131c4bc47d198bc2ed1340ca15e', start_time=1662637629469, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.400228681203018}, params={'alpha': '0.9102330084707424'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/150390f766ec4eca829e39ea8978f584/artifacts', end_time=1662637629389, experiment_id='1', lifecycle_stage='active', run_id='150390f766ec4eca829e39ea8978f584', run_uuid='150390f766ec4eca829e39ea8978f584', start_time=1662637628346, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39877760112128}, params={'alpha': '0.44773272479631426'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/95399f6384104a7fa8f9d6e5a1463754/artifacts', end_time=1662637628250, experiment_id='1', lifecycle_stage='active', run_id='95399f6384104a7fa8f9d6e5a1463754', run_uuid='95399f6384104a7fa8f9d6e5a1463754', start_time=1662637627245, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.396058763154901}, params={'alpha': '0.8288446838343801'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/91792e0923484e3a9c773a1d72eadf87/artifacts', end_time=1662637627154, experiment_id='1', lifecycle_stage='active', run_id='91792e0923484e3a9c773a1d72eadf87', run_uuid='91792e0923484e3a9c773a1d72eadf87', start_time=1662637626167, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/c9288ea7a6ef4f70a83f12c20cabe4a2/artifacts', end_time=1662637626070, experiment_id='1', lifecycle_stage='active', run_id='c9288ea7a6ef4f70a83f12c20cabe4a2', run_uuid='c9288ea7a6ef4f70a83f12c20cabe4a2', start_time=1662637625021, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.log-model.history': '[{"run_id": "fda735cf0d1140ba9d02edf17caac890", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2022-09-08 10:55:31.744183", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"loader_module": "mlflow.sklearn", '
#                               '"python_version": "3.9.12", "env": '
#                               '"conda.yaml"}, "sklearn": {"pickled_model": '
#                               '"model.pkl", "sklearn_version": "1.0.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"808a7efc02f6449f9ea1ddbc9c8351dd", '
#                               '"mlflow_version": "1.28.0"}]',
#   'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/fda735cf0d1140ba9d02edf17caac890/artifacts', end_time=1662634534925, experiment_id='1', lifecycle_stage='active', run_id='fda735cf0d1140ba9d02edf17caac890', run_uuid='fda735cf0d1140ba9d02edf17caac890', start_time=1662634526413, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.411816641532287}, params={'alpha': '0.3406991284146929'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/7121cb29b2464d1f99aa5506c2f824c0/artifacts', end_time=1662634526310, experiment_id='1', lifecycle_stage='active', run_id='7121cb29b2464d1f99aa5506c2f824c0', run_uuid='7121cb29b2464d1f99aa5506c2f824c0', start_time=1662634525220, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.394184574038444}, params={'alpha': '0.506849894895767'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/dd5bd31b86b6419ea6958e11bb6d1883/artifacts', end_time=1662634525132, experiment_id='1', lifecycle_stage='active', run_id='dd5bd31b86b6419ea6958e11bb6d1883', run_uuid='dd5bd31b86b6419ea6958e11bb6d1883', start_time=1662634524006, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.455377317732182}, params={'alpha': '0.16793791172232522'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/62799daaf3414499a0e112cca87e621e/artifacts', end_time=1662634523913, experiment_id='1', lifecycle_stage='active', run_id='62799daaf3414499a0e112cca87e621e', run_uuid='62799daaf3414499a0e112cca87e621e', start_time=1662634522755, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.391526068627218}, params={'alpha': '0.7321554052259304'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/d60bdc3edf3b456f85f293481fed441b/artifacts', end_time=1662634522664, experiment_id='1', lifecycle_stage='active', run_id='d60bdc3edf3b456f85f293481fed441b', run_uuid='d60bdc3edf3b456f85f293481fed441b', start_time=1662634521600, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.405640754327791}, params={'alpha': '0.9983678625682587'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/0128bd5796a640a09e30e02c84e42ef2/artifacts', end_time=1662634521488, experiment_id='1', lifecycle_stage='active', run_id='0128bd5796a640a09e30e02c84e42ef2', run_uuid='0128bd5796a640a09e30e02c84e42ef2', start_time=1662634520414, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39193708706294}, params={'alpha': '0.5509362875686761'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/6b3613c5d2ce4888840ea63c37b2cb15/artifacts', end_time=1662634520326, experiment_id='1', lifecycle_stage='active', run_id='6b3613c5d2ce4888840ea63c37b2cb15', run_uuid='6b3613c5d2ce4888840ea63c37b2cb15', start_time=1662634519225, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.400228681203018}, params={'alpha': '0.9102330084707424'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/27e94bed18de4a1087ec3ed324e5fca1/artifacts', end_time=1662634519096, experiment_id='1', lifecycle_stage='active', run_id='27e94bed18de4a1087ec3ed324e5fca1', run_uuid='27e94bed18de4a1087ec3ed324e5fca1', start_time=1662634518099, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39877760112128}, params={'alpha': '0.44773272479631426'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/12e5a08ea80a4accb711a7eff684e2b7/artifacts', end_time=1662634518002, experiment_id='1', lifecycle_stage='active', run_id='12e5a08ea80a4accb711a7eff684e2b7', run_uuid='12e5a08ea80a4accb711a7eff684e2b7', start_time=1662634516781, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.396058763154901}, params={'alpha': '0.8288446838343801'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/38e23199ed99473aa048ee70053beb5d/artifacts', end_time=1662634516676, experiment_id='1', lifecycle_stage='active', run_id='38e23199ed99473aa048ee70053beb5d', run_uuid='38e23199ed99473aa048ee70053beb5d', start_time=1662634515486, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/0fb45efaf3cc45de9bad468ce9e867c0/artifacts', end_time=1662634515294, experiment_id='1', lifecycle_stage='active', run_id='0fb45efaf3cc45de9bad468ce9e867c0', run_uuid='0fb45efaf3cc45de9bad468ce9e867c0', start_time=1662634514162, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.log-model.history': '[{"run_id": "352cbbdadc9a41c386e19187c6f377d3", '
#                               '"artifact_path": "models", "utc_time_created": '
#                               '"2022-09-08 10:48:04.594104", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"loader_module": "mlflow.sklearn", '
#                               '"python_version": "3.9.12", "env": '
#                               '"conda.yaml"}, "sklearn": {"pickled_model": '
#                               '"model.pkl", "sklearn_version": "1.0.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"f51a13aba74d4d29974351a66b5dbdc9", '
#                               '"mlflow_version": "1.28.0"}]',
#   'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/352cbbdadc9a41c386e19187c6f377d3/artifacts', end_time=1662634088018, experiment_id='1', lifecycle_stage='active', run_id='352cbbdadc9a41c386e19187c6f377d3', run_uuid='352cbbdadc9a41c386e19187c6f377d3', start_time=1662634080537, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.411816641532287}, params={'alpha': '0.3406991284146929'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/434ad23c18f64076b0d34b731570152a/artifacts', end_time=1662634080443, experiment_id='1', lifecycle_stage='active', run_id='434ad23c18f64076b0d34b731570152a', run_uuid='434ad23c18f64076b0d34b731570152a', start_time=1662634079278, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.394184574038444}, params={'alpha': '0.506849894895767'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/b0fb38004fda4c968464d76de18282d2/artifacts', end_time=1662634079172, experiment_id='1', lifecycle_stage='active', run_id='b0fb38004fda4c968464d76de18282d2', run_uuid='b0fb38004fda4c968464d76de18282d2', start_time=1662634077978, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.455377317732182}, params={'alpha': '0.16793791172232522'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/4f293c7bc988487aaa96fb6bfd97b8cd/artifacts', end_time=1662634077858, experiment_id='1', lifecycle_stage='active', run_id='4f293c7bc988487aaa96fb6bfd97b8cd', run_uuid='4f293c7bc988487aaa96fb6bfd97b8cd', start_time=1662634076679, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.391526068627218}, params={'alpha': '0.7321554052259304'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/10bb3884452a4d89b5880d3007722401/artifacts', end_time=1662634076578, experiment_id='1', lifecycle_stage='active', run_id='10bb3884452a4d89b5880d3007722401', run_uuid='10bb3884452a4d89b5880d3007722401', start_time=1662634075536, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.405640754327791}, params={'alpha': '0.9983678625682587'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/2cc2e93f74884a66896a6d20e1639325/artifacts', end_time=1662634075432, experiment_id='1', lifecycle_stage='active', run_id='2cc2e93f74884a66896a6d20e1639325', run_uuid='2cc2e93f74884a66896a6d20e1639325', start_time=1662634074327, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39193708706294}, params={'alpha': '0.5509362875686761'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/a91b39256a604b66ac523142d135a6ff/artifacts', end_time=1662634074197, experiment_id='1', lifecycle_stage='active', run_id='a91b39256a604b66ac523142d135a6ff', run_uuid='a91b39256a604b66ac523142d135a6ff', start_time=1662634073111, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.400228681203018}, params={'alpha': '0.9102330084707424'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/84ace2dc0e224a4a97e2d6a57fdfe646/artifacts', end_time=1662634072986, experiment_id='1', lifecycle_stage='active', run_id='84ace2dc0e224a4a97e2d6a57fdfe646', run_uuid='84ace2dc0e224a4a97e2d6a57fdfe646', start_time=1662634071473, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39877760112128}, params={'alpha': '0.44773272479631426'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/bd8586ab690c45daa0af542a23e303b1/artifacts', end_time=1662634071348, experiment_id='1', lifecycle_stage='active', run_id='bd8586ab690c45daa0af542a23e303b1', run_uuid='bd8586ab690c45daa0af542a23e303b1', start_time=1662634070148, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.396058763154901}, params={'alpha': '0.8288446838343801'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/1c4cbb95cd9f45ca94001f78fda51e79/artifacts', end_time=1662634070014, experiment_id='1', lifecycle_stage='active', run_id='1c4cbb95cd9f45ca94001f78fda51e79', run_uuid='1c4cbb95cd9f45ca94001f78fda51e79', start_time=1662634068479, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/a2612ff9f0104f4c904fe6fa43d5357f/artifacts', end_time=1662634068368, experiment_id='1', lifecycle_stage='active', run_id='a2612ff9f0104f4c904fe6fa43d5357f', run_uuid='a2612ff9f0104f4c904fe6fa43d5357f', start_time=1662634066365, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.log-model.history': '[{"run_id": "6d807eecb60a446ea6080472df20784c", '
#                               '"artifact_path": "models", "utc_time_created": '
#                               '"2022-09-08 10:14:44.205846", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"loader_module": "mlflow.sklearn", '
#                               '"python_version": "3.9.12", "env": '
#                               '"conda.yaml"}, "sklearn": {"pickled_model": '
#                               '"model.pkl", "sklearn_version": "1.0.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"fb75abbdb1c342919942f18924e2e723", '
#                               '"mlflow_version": "1.28.0"}]',
#   'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/6d807eecb60a446ea6080472df20784c/artifacts', end_time=1662632087020, experiment_id='1', lifecycle_stage='active', run_id='6d807eecb60a446ea6080472df20784c', run_uuid='6d807eecb60a446ea6080472df20784c', start_time=1662632079890, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.411816641532287}, params={'alpha': '0.3406991284146929'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/9e2423f7ec7047feb37c7dda83c9ed39/artifacts', end_time=1662632079784, experiment_id='1', lifecycle_stage='active', run_id='9e2423f7ec7047feb37c7dda83c9ed39', run_uuid='9e2423f7ec7047feb37c7dda83c9ed39', start_time=1662632078641, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.394184574038444}, params={'alpha': '0.506849894895767'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/7136ad50e9a74fd78b1f22e7ef319c79/artifacts', end_time=1662632078568, experiment_id='1', lifecycle_stage='active', run_id='7136ad50e9a74fd78b1f22e7ef319c79', run_uuid='7136ad50e9a74fd78b1f22e7ef319c79', start_time=1662632077565, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.455377317732182}, params={'alpha': '0.16793791172232522'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/0dd76a36ed6341799cbd3114313ee562/artifacts', end_time=1662632077479, experiment_id='1', lifecycle_stage='active', run_id='0dd76a36ed6341799cbd3114313ee562', run_uuid='0dd76a36ed6341799cbd3114313ee562', start_time=1662632076413, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.391526068627218}, params={'alpha': '0.7321554052259304'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/089c4fd6601a4f12ac705117653b605d/artifacts', end_time=1662632076328, experiment_id='1', lifecycle_stage='active', run_id='089c4fd6601a4f12ac705117653b605d', run_uuid='089c4fd6601a4f12ac705117653b605d', start_time=1662632075252, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.405640754327791}, params={'alpha': '0.9983678625682587'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/9a083d14acdb4916bc7826ad53eb1f0e/artifacts', end_time=1662632075133, experiment_id='1', lifecycle_stage='active', run_id='9a083d14acdb4916bc7826ad53eb1f0e', run_uuid='9a083d14acdb4916bc7826ad53eb1f0e', start_time=1662632074173, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39193708706294}, params={'alpha': '0.5509362875686761'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/5009f01133504a72923a484b71ef7fb0/artifacts', end_time=1662632074079, experiment_id='1', lifecycle_stage='active', run_id='5009f01133504a72923a484b71ef7fb0', run_uuid='5009f01133504a72923a484b71ef7fb0', start_time=1662632073066, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.400228681203018}, params={'alpha': '0.9102330084707424'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/b4bb780edc534b4f8a939826f0f8a42b/artifacts', end_time=1662632072984, experiment_id='1', lifecycle_stage='active', run_id='b4bb780edc534b4f8a939826f0f8a42b', run_uuid='b4bb780edc534b4f8a939826f0f8a42b', start_time=1662632071955, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39877760112128}, params={'alpha': '0.44773272479631426'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/cbe6f8e3f7644e14823794e61ec412c0/artifacts', end_time=1662632071877, experiment_id='1', lifecycle_stage='active', run_id='cbe6f8e3f7644e14823794e61ec412c0', run_uuid='cbe6f8e3f7644e14823794e61ec412c0', start_time=1662632070867, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.396058763154901}, params={'alpha': '0.8288446838343801'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/e50a2e4afa384da6bafe7e0efecf5524/artifacts', end_time=1662632070772, experiment_id='1', lifecycle_stage='active', run_id='e50a2e4afa384da6bafe7e0efecf5524', run_uuid='e50a2e4afa384da6bafe7e0efecf5524', start_time=1662632069797, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/2123bbcb9557436f945ebff219a33f39/artifacts', end_time=1662632069715, experiment_id='1', lifecycle_stage='active', run_id='2123bbcb9557436f945ebff219a33f39', run_uuid='2123bbcb9557436f945ebff219a33f39', start_time=1662632068706, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.log-model.history': '[{"run_id": "35948141c3454e709c64ad940601f03f", '
#                               '"artifact_path": "models", "utc_time_created": '
#                               '"2022-09-08 10:14:08.220029", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"loader_module": "mlflow.sklearn", '
#                               '"python_version": "3.9.12", "env": '
#                               '"conda.yaml"}, "sklearn": {"pickled_model": '
#                               '"model.pkl", "sklearn_version": "1.0.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"387b0d7960264b6c9c1d42b229658332", '
#                               '"mlflow_version": "1.28.0"}]',
#   'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/35948141c3454e709c64ad940601f03f/artifacts', end_time=1662632051102, experiment_id='1', lifecycle_stage='active', run_id='35948141c3454e709c64ad940601f03f', run_uuid='35948141c3454e709c64ad940601f03f', start_time=1662632043711, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.411816641532287}, params={'alpha': '0.3406991284146929'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/7aae1b4b2f054d668df83824bcfd317f/artifacts', end_time=1662632043595, experiment_id='1', lifecycle_stage='active', run_id='7aae1b4b2f054d668df83824bcfd317f', run_uuid='7aae1b4b2f054d668df83824bcfd317f', start_time=1662632042493, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.394184574038444}, params={'alpha': '0.506849894895767'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/40b7bc1908964396a09c84e0258b3f8e/artifacts', end_time=1662632042378, experiment_id='1', lifecycle_stage='active', run_id='40b7bc1908964396a09c84e0258b3f8e', run_uuid='40b7bc1908964396a09c84e0258b3f8e', start_time=1662632041340, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.455377317732182}, params={'alpha': '0.16793791172232522'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/e4544bb5711f49feb1ff0c315d95c681/artifacts', end_time=1662632041250, experiment_id='1', lifecycle_stage='active', run_id='e4544bb5711f49feb1ff0c315d95c681', run_uuid='e4544bb5711f49feb1ff0c315d95c681', start_time=1662632040069, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.391526068627218}, params={'alpha': '0.7321554052259304'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/7d14e433d0d04938938291c739da1388/artifacts', end_time=1662632039947, experiment_id='1', lifecycle_stage='active', run_id='7d14e433d0d04938938291c739da1388', run_uuid='7d14e433d0d04938938291c739da1388', start_time=1662632038925, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.405640754327791}, params={'alpha': '0.9983678625682587'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/dd2305419c9e4a9182c157994eeec803/artifacts', end_time=1662632038823, experiment_id='1', lifecycle_stage='active', run_id='dd2305419c9e4a9182c157994eeec803', run_uuid='dd2305419c9e4a9182c157994eeec803', start_time=1662632037842, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39193708706294}, params={'alpha': '0.5509362875686761'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/599af75a94a14b7cbe25a570bc271cfd/artifacts', end_time=1662632037770, experiment_id='1', lifecycle_stage='active', run_id='599af75a94a14b7cbe25a570bc271cfd', run_uuid='599af75a94a14b7cbe25a570bc271cfd', start_time=1662632036780, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.400228681203018}, params={'alpha': '0.9102330084707424'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/8cf25d7bf7d6426a91d7ddcbe7f04806/artifacts', end_time=1662632036697, experiment_id='1', lifecycle_stage='active', run_id='8cf25d7bf7d6426a91d7ddcbe7f04806', run_uuid='8cf25d7bf7d6426a91d7ddcbe7f04806', start_time=1662632035797, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39877760112128}, params={'alpha': '0.44773272479631426'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/d0317f9730604ff9ba1ba0945f299eb6/artifacts', end_time=1662632035713, experiment_id='1', lifecycle_stage='active', run_id='d0317f9730604ff9ba1ba0945f299eb6', run_uuid='d0317f9730604ff9ba1ba0945f299eb6', start_time=1662632034642, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.396058763154901}, params={'alpha': '0.8288446838343801'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/5a4d14e7dc2648b3b969db291d2447f2/artifacts', end_time=1662632034526, experiment_id='1', lifecycle_stage='active', run_id='5a4d14e7dc2648b3b969db291d2447f2', run_uuid='5a4d14e7dc2648b3b969db291d2447f2', start_time=1662632033519, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/3ab218a82f6f4f17991be2de4e2df5b9/artifacts', end_time=1662632033398, experiment_id='1', lifecycle_stage='active', run_id='3ab218a82f6f4f17991be2de4e2df5b9', run_uuid='3ab218a82f6f4f17991be2de4e2df5b9', start_time=1662632032325, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.411816641532287}, params={'alpha': '0.3406991284146929'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/3a0621eb1eaf4aaabeeacc8cbde8600f/artifacts', end_time=1662632010641, experiment_id='1', lifecycle_stage='active', run_id='3a0621eb1eaf4aaabeeacc8cbde8600f', run_uuid='3a0621eb1eaf4aaabeeacc8cbde8600f', start_time=1662632009510, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.394184574038444}, params={'alpha': '0.506849894895767'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/87e4703e6a804627b82ef29d4e2fed3e/artifacts', end_time=1662632009369, experiment_id='1', lifecycle_stage='active', run_id='87e4703e6a804627b82ef29d4e2fed3e', run_uuid='87e4703e6a804627b82ef29d4e2fed3e', start_time=1662632008336, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.455377317732182}, params={'alpha': '0.16793791172232522'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/172eecb5c700442482d6c9f09b9c584c/artifacts', end_time=1662632008245, experiment_id='1', lifecycle_stage='active', run_id='172eecb5c700442482d6c9f09b9c584c', run_uuid='172eecb5c700442482d6c9f09b9c584c', start_time=1662632007135, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.391526068627218}, params={'alpha': '0.7321554052259304'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/b4a42e717e714a2caa9bd2be906d27cd/artifacts', end_time=1662632007046, experiment_id='1', lifecycle_stage='active', run_id='b4a42e717e714a2caa9bd2be906d27cd', run_uuid='b4a42e717e714a2caa9bd2be906d27cd', start_time=1662632006022, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.405640754327791}, params={'alpha': '0.9983678625682587'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/723be74334ad413d8b94084d288f4807/artifacts', end_time=1662632005919, experiment_id='1', lifecycle_stage='active', run_id='723be74334ad413d8b94084d288f4807', run_uuid='723be74334ad413d8b94084d288f4807', start_time=1662632004847, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39193708706294}, params={'alpha': '0.5509362875686761'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/ee52b37727e7463195aedbbefe3b1fed/artifacts', end_time=1662632004761, experiment_id='1', lifecycle_stage='active', run_id='ee52b37727e7463195aedbbefe3b1fed', run_uuid='ee52b37727e7463195aedbbefe3b1fed', start_time=1662632003695, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.400228681203018}, params={'alpha': '0.9102330084707424'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/26f6aaa569a040f39ebb86abf6259020/artifacts', end_time=1662632003605, experiment_id='1', lifecycle_stage='active', run_id='26f6aaa569a040f39ebb86abf6259020', run_uuid='26f6aaa569a040f39ebb86abf6259020', start_time=1662632002556, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39877760112128}, params={'alpha': '0.44773272479631426'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/2530c7e405954674a30d01ed4c040142/artifacts', end_time=1662632002444, experiment_id='1', lifecycle_stage='active', run_id='2530c7e405954674a30d01ed4c040142', run_uuid='2530c7e405954674a30d01ed4c040142', start_time=1662632001391, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.396058763154901}, params={'alpha': '0.8288446838343801'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/dda6952c8fa842fa9db918c6180aa271/artifacts', end_time=1662632001273, experiment_id='1', lifecycle_stage='active', run_id='dda6952c8fa842fa9db918c6180aa271', run_uuid='dda6952c8fa842fa9db918c6180aa271', start_time=1662632000175, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.390913317033252}, params={'alpha': '0.6854409845387625'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/b89ba52ba4864e4b862f5d66588f5a69/artifacts', end_time=1662632000095, experiment_id='1', lifecycle_stage='active', run_id='b89ba52ba4864e4b862f5d66588f5a69', run_uuid='b89ba52ba4864e4b862f5d66588f5a69', start_time=1662631999080, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.39183167141086}, params={'alpha': '0.5917602614260692'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/0a1027b3fdb445928f1e45b35ef5e7da/artifacts', end_time=1662629426425, experiment_id='1', lifecycle_stage='active', run_id='0a1027b3fdb445928f1e45b35ef5e7da', run_uuid='0a1027b3fdb445928f1e45b35ef5e7da', start_time=1662629425342, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.400313900527172}, params={'alpha': '0.9183936440643112'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/2a79833bbe9043769faa4cbb6db3e8e4/artifacts', end_time=1662629425234, experiment_id='1', lifecycle_stage='active', run_id='2a79833bbe9043769faa4cbb6db3e8e4', run_uuid='2a79833bbe9043769faa4cbb6db3e8e4', start_time=1662629424191, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.394754106659988}, params={'alpha': '0.497938840723922'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/6808d88acd9c416a831e2be59cce52bb/artifacts', end_time=1662629424110, experiment_id='1', lifecycle_stage='active', run_id='6808d88acd9c416a831e2be59cce52bb', run_uuid='6808d88acd9c416a831e2be59cce52bb', start_time=1662629423004, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.3970216039868}, params={'alpha': '0.8444042580312547'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/58bff6ea72f143979c421f327d16a4b8/artifacts', end_time=1662629422911, experiment_id='1', lifecycle_stage='active', run_id='58bff6ea72f143979c421f327d16a4b8', run_uuid='58bff6ea72f143979c421f327d16a4b8', start_time=1662629421852, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.391206348056755}, params={'alpha': '0.7140372586716023'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/5844394dc68b416c8db3a839ca5c4da9/artifacts', end_time=1662629421704, experiment_id='1', lifecycle_stage='active', run_id='5844394dc68b416c8db3a839ca5c4da9', run_uuid='5844394dc68b416c8db3a839ca5c4da9', start_time=1662629420517, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.5391502413888}, params={'alpha': '0'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/70471c982b7e4aad9e950ac29b84afd7/artifacts', end_time=1662629068006, experiment_id='1', lifecycle_stage='active', run_id='70471c982b7e4aad9e950ac29b84afd7', run_uuid='70471c982b7e4aad9e950ac29b84afd7', start_time=1662629066762, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.5391502413888}, params={'alpha': '0'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/c707e306c8ae4d6c813ec3606487d304/artifacts', end_time=1662629066663, experiment_id='1', lifecycle_stage='active', run_id='c707e306c8ae4d6c813ec3606487d304', run_uuid='c707e306c8ae4d6c813ec3606487d304', start_time=1662629065342, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.5391502413888}, params={'alpha': '0'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/a40b9126b31d4375bcf8a60eb3ef03c4/artifacts', end_time=1662629065235, experiment_id='1', lifecycle_stage='active', run_id='a40b9126b31d4375bcf8a60eb3ef03c4', run_uuid='a40b9126b31d4375bcf8a60eb3ef03c4', start_time=1662629063897, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.5391502413888}, params={'alpha': '0'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/98401d3fd8c8440c95e9535a917fdeee/artifacts', end_time=1662629063766, experiment_id='1', lifecycle_stage='active', run_id='98401d3fd8c8440c95e9535a917fdeee', run_uuid='98401d3fd8c8440c95e9535a917fdeee', start_time=1662629062467, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'RMSE': 14.5391502413888}, params={'alpha': '0'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/e0ae9b59ec524b969f45d5ff45cb66b3/artifacts', end_time=1662629062356, experiment_id='1', lifecycle_stage='active', run_id='e0ae9b59ec524b969f45d5ff45cb66b3', run_uuid='e0ae9b59ec524b969f45d5ff45cb66b3', start_time=1662629061094, status='FINISHED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={}, params={'alpha': '0'}, tags={'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell',
#   'model': 'Ridge'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/fe7acb1a6d0142ed84b653bd34cd439b/artifacts', end_time=1662628930873, experiment_id='1', lifecycle_stage='active', run_id='fe7acb1a6d0142ed84b653bd34cd439b', run_uuid='fe7acb1a6d0142ed84b653bd34cd439b', start_time=1662628930555, status='FAILED', user_id='keiranoconnell'>>,
#  <Run: data=<RunData: metrics={'mean_squared_error': 14.405431269954295}, params={'alpha': '1', 'random_state': '0'}, tags={'mlflow.log-model.history': '[{"run_id": "c241128457cf45c08ef3779bb02d0fd6", '
#                               '"artifact_path": "models", "utc_time_created": '
#                               '"2022-09-08 09:13:13.807405", "flavors": '
#                               '{"python_function": {"model_path": "model.pkl", '
#                               '"loader_module": "mlflow.sklearn", '
#                               '"python_version": "3.9.12", "env": '
#                               '"conda.yaml"}, "sklearn": {"pickled_model": '
#                               '"model.pkl", "sklearn_version": "1.0.2", '
#                               '"serialization_format": "cloudpickle", "code": '
#                               'null}}, "model_uuid": '
#                               '"805f2e54010249468e168ace9f721838", '
#                               '"mlflow_version": "1.28.0"}]',
#   'mlflow.source.git.commit': 'c5731faf8be1ddc1eeae4b162b88bd76318fc279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/mlops/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'keiranoconnell'}>, info=<RunInfo: artifact_uri='s3://mlflow-artifacts-remote-2/1/c241128457cf45c08ef3779bb02d0fd6/artifacts', end_time=1662628398738, experiment_id='1', lifecycle_stage='active', run_id='c241128457cf45c08ef3779bb02d0fd6', run_uuid='c241128457cf45c08ef3779bb02d0fd6', start_time=1662628391676, status='FINISHED', user_id='keiranoconnell'>>]

# %%
experiment = client.get_experiment_by_name(EXPERIMENT_NAME)
experiment.artifact_location
# Out:
# 's3://mlflow-artifacts-remote-2/1'

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment('bikeshare-ride-duration-prediction')
# Out:
# <Experiment: artifact_location='s3://mlflow-artifacts-remote-2/1', experiment_id='1', lifecycle_stage='active', name='bikeshare-ride-duration-prediction', tags={}>

# %%
apply_model(client)
# Out:
# (243756, 54362) (60939, 54362) (243756,) (60939,)
# DictVectorizer()
# 100%|██████████| 10/10 [00:11<00:00,  1.14s/trial, best loss: 14.390913317033252]
# Best params: {'alpha': 0.6854409845387625}
# RMSE: 14.390913317033252
# Run ID: b9ea23fdd14043a8827497b800da057f
# Registered model 'bikeshare-ride-duration-regressor' already exists. Creating a new version of this model...
# 2022/09/08 21:47:23 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: bikeshare-ride-duration-regressor, version 3
# Created version '3' of model 'bikeshare-ride-duration-regressor'.

# %%
model_version = client.get_latest_versions(MODEL_NAME)[-1].version
transition_model_stage(client, MODEL_NAME, model_version, 'Production')

# %%
client.get_latest_versions(MODEL_NAME, ['Production'])[0]
# Out:
# <ModelVersion: creation_timestamp=1662982796229, current_stage='Production', description='', last_updated_timestamp=1662982975334, name='bikeshare-ride-duration-regressor', run_id='ea139ca8e97f457d911ffb831f69ab6a', run_link='', source='s3://mlflow-artifacts-remote-2/1/ea139ca8e97f457d911ffb831f69ab6a/artifacts/model', status='READY', status_message='', tags={'run_id': 'ea139ca8e97f457d911ffb831f69ab6a'}, user_id='', version='12'>
